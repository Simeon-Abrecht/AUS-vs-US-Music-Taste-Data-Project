# %%
import sys

sys.path.append("/Workspace/AUS vs US Music Taste/AUS-vs-US-Music-Taste-Data-Project/src")
import pandas as pd
from pathlib import Path
import clean_df
import importlib
importlib.reload(clean_df)  # Reload to pick up changes

input_dir = Path("/Workspace/AUS vs US Music Taste/AUS-vs-US-Music-Taste-Data-Project/Data/Raw/Aria")

# %% [markdown]
# ### Performs the following actions on the raw Arias dataframe
# -  Renames headers to standarised form ["rank", "song_title", "artist", "year"]
# - Removes B side songs in the list (two songs counting as the same single)
# -  Removes double braces "{{}}" around certain artists
# - Removes unneccesary artefacts like "{re-release}" from song title column
# - Saves cleaned csv to bronze Aria folder

# %%
csv_files = sorted(input_dir.glob("*.csv"))
i = 2000
for csv_file in csv_files: 
    df = pd.read_csv(csv_file)
    df = clean_df.rename_headers(df, ["rank", "song_title", "artist", "year"])
    df = clean_df.drop_b_sides(df)
    df = clean_df.remove_double_braces(df)
    df = clean_df.remove_artefacts(df)
    df.to_csv(f'/Workspace/AUS vs US Music Taste/AUS-vs-US-Music-Taste-Data-Project/Data/Bronze/Aria_bronze/Aria_{i}.csv', index=False)
    i+=1
