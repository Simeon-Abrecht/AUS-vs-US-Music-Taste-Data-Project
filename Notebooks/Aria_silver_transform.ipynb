# %%
import sys

sys.path.append("/Workspace/AUS vs US Music Taste/AUS-vs-US-Music-Taste-Data-Project/src")
import pandas as pd
from pathlib import Path
import artist_handling
import importlib
importlib.reload(artist_handling)  # Reload to pick up changes


input_dir = Path("/Workspace/AUS vs US Music Taste/AUS-vs-US-Music-Taste-Data-Project/Data/Bronze/Aria_bronze")

# %%
trial_df = pd.read_csv("/Workspace/AUS vs US Music Taste/AUS-vs-US-Music-Taste-Data-Project/Data/Bronze/Aria_bronze/Aria_2015.csv")

# %%
trial_df[['main_artist', 'featuring_artists']] = trial_df['artist'].apply(artist_handling.split_artists)

# %%
display(trial_df)
