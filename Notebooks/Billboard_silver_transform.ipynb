# %%
# %python
#!pip install musicbrainzngs

# %%
# %python
import sys

sys.path.append("/Workspace/AUS vs US Music Taste/AUS-vs-US-Music-Taste-Data-Project/src")
import pandas as pd
from pathlib import Path
import artist_handling
import TrackInfo 
import importlib
import musicbrainzngs
import requests
importlib.reload(artist_handling)  # Reload to pick up changes

# %%
# %python
df = pd.read_csv("/Workspace/AUS vs US Music Taste/AUS-vs-US-Music-Taste-Data-Project/Data/Bronze/Billboard_bronze/billboard_2007.csv")
display(df)

# %%
# %python
df[['main_artist', 'featuring_artists']] = df['artist'].apply(artist_handling.split_artists_billboard)
    

# 1. Drop the original artist column
df = df.drop(columns=["artist"])

# 2. Rename main_artist → artist
df = df.rename(columns={"main_artist": "artist"})

# 3. Reorder columns
df = df[["rank", "song_title", "artist", "featuring_artists", "year"]]

# %%
# %python
display(df)

# %%
# %python
df = TrackInfo.add_track_info(df)
display(df)

# %%
# %python
df2 = df.copy()

# %%
# %python
df2["genre"] = df2["toptags"].apply(TrackInfo.clean_genre_tags)
display(df2)

# %%
df2 = df2.drop(columns=["toptags"])

# %%
display(df2)

# %%
# %python
input_dir = Path("/Workspace/AUS vs US Music Taste/AUS-vs-US-Music-Taste-Data-Project/Data/Bronze/Billboard_bronze")
csv_files = sorted(input_dir.glob("*.csv"))
i = 2000
for csv_file in csv_files: 
    df = pd.read_csv(csv_file)
    df[['main_artist', 'featuring_artists']] = df['artist'].apply(artist_handling.split_artists)
    

    # 1. Drop the original artist column
    df = df.drop(columns=["artist"])

    # 2. Rename main_artist → artist
    df = df.rename(columns={"main_artist": "artist"})

    # 3. Reorder columns
    df = df[["rank", "song_title", "artist", "featuring_artists", "year"]]
    df = TrackInfo.add_track_info(df)

    df["genre"] = df["toptags"].apply(TrackInfo.clean_genre_tags)
    
    df = df.drop(columns=["toptags"])

    df.to_csv(f'/Workspace/AUS vs US Music Taste/AUS-vs-US-Music-Taste-Data-Project/Data/Silver/Billboard_silver/Billboard_{i}.csv', index=False)
    i+=1

# %%
csv_files = ["/Workspace/AUS vs US Music Taste/AUS-vs-US-Music-Taste-Data-Project/Data/Bronze/Billboard_bronze/billboard_2024.csv", "/Workspace/AUS vs US Music Taste/AUS-vs-US-Music-Taste-Data-Project/Data/Bronze/Billboard_bronze/billboard_2025.csv"]

i = 2024

for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    df[['main_artist', 'featuring_artists']] = df['artist'].apply(artist_handling.split_artists)
    

    # 1. Drop the original artist column
    df = df.drop(columns=["artist"])

    # 2. Rename main_artist → artist
    df = df.rename(columns={"main_artist": "artist"})

    # 3. Reorder columns
    df = df[["rank", "song_title", "artist", "featuring_artists", "year"]]
    df = TrackInfo.add_track_info(df)

    df["genre"] = df["toptags"].apply(TrackInfo.clean_genre_tags)
    
    df = df.drop(columns=["toptags"])

    df.to_csv(f'/Workspace/AUS vs US Music Taste/AUS-vs-US-Music-Taste-Data-Project/Data/Silver/Billboard_silver/Billboard_{i}.csv', index=False)
    i+=1
